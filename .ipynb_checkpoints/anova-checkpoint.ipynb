# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("exams.csv")
df.head()

# %%
df.describe()
# Out:
#         math score  reading score  writing score
# count  1000.000000    1000.000000    1000.000000
# mean     66.396000      69.002000      67.738000
# std      15.402871      14.737272      15.600985
# min      13.000000      27.000000      23.000000
# 25%      56.000000      60.000000      58.000000
# 50%      66.500000      70.000000      68.000000
# 75%      77.000000      79.000000      79.000000
# max     100.000000     100.000000     100.000000

# %%
all_men = df[df["gender"]=="male"]

all_men.hist( column="reading score" ,bins=10)
# Out:
# array([[<AxesSubplot: title={'center': 'reading score'}>]], dtype=object)

# %%
all_men.hist(column="math score", bins=5)
# Out:
# array([[<AxesSubplot: title={'center': 'math score'}>]], dtype=object)
