# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %%
likert = pd.read_csv("output_2023_april.csv")

# %%
likert['T1'].replace(["très d'accord", "d'accord", "neutre", "désaccord" , "totalement en désaccord"], [5, 4 , 3 , 2 , 1], inplace = True)
likert['T2'].replace(["très d'accord", "d'accord", "neutre", "désaccord" , "totalement en désaccord"], [5, 4 , 3 , 2 , 1], inplace = True)
likert['T3'].replace(["très d'accord", "d'accord", "neutre", "désaccord" , "totalement en désaccord"], [5, 4 , 3 , 2 , 1], inplace = True)
likert['T4'].replace(["très d'accord", "d'accord", "neutre", "désaccord" , "totalement en désaccord"], [5, 4 , 3 , 2 , 1], inplace = True)
likert['T5'].replace(["Très fort", "Fort", "Moyen", "Faible" , "Très faible"], [5, 4 , 3 , 2 , 1], inplace = True)
likert['T6'].replace(["Haute Résilience, je coupe chaque appareil électrique après utilisation et chauffage.", "Résilience légère, tant qu'on me coupe pas l'électricité.", "Résilience moyenne, je suis prêt à m'investir un minimum et réduire ma consommation.", "Peu de résilience , je suis prêt à m'investir que si l'on m'y force." , "Aucune résilience, je refuse de m'adapter."], [5, 4 , 3 , 2 , 1], inplace = True)
likert['T7'].replace(["Très optimiste", "Optimiste", "Neutre", "Pessimiste" , "Très pessimiste"], [5, 4 , 3 , 2 , 1], inplace = True)
likert['T8'].replace(["Très flexible", "Flexible", "Ni flexible ni inflexible", "Inflexible" , "Très inflexible"], [5, 4 , 3 , 2 , 1], inplace = True)
likert['T9'].replace(["Je suis en mesure de surmonter les difficultés de manière positive.", "Je gère le stress de manière efficace et je m'adapte rapidement aux changements", "Je m'inquiète un peu, mais je finis par m'en remettre.", "Je m'inquiète beaucoup et j'ai du mal à m'en remettre." , "Je m'effondre et je me sens incapable de faire face."], [5, 4 , 3 , 2 , 1], inplace = True)
likert['T10'].replace(["Tout à fait d'accord", "Plutôt d'accord", "Ni d'accord ni de désaccord", "Peu d'accord" , "Pas du tout d'accord"], [5, 4 , 3 , 2 , 1], inplace = True)
likert['T11'].replace(["Tout à fait d'accord", "Plutôt d'accord", "Ni d'accord ni de désaccord", "Peu d'accord" , "Pas du tout d'accord"],[5, 4 , 3 , 2 , 1], inplace = True)

# %%
likert.drop(["Unnamed: 0"], axis=1, inplace=True)

# %%
likert
# Out:
#      Sexe      Age  T1  T2  T3  T4  T5  T6  T7  T8  T9  T10  T11
# 0   Homme  21 - 25   4   4   3   4   3   3   4   4   3    2    4
# 1   Femme  18 - 20   5   5   1   5   4   5   3   4   2    4    4
# 2   Femme  26 - 30   5   4   2   4   3   4   3   4   3    4    2
# 3   Femme  21 - 25   5   5   4   5   5   3   3   4   5    4    3
# 4   Homme  21 - 25   5   5   3   5   5   5   5   5   3    5    4
# 5   Homme  18 - 20   5   4   3   4   3   4   2   3   3    3    2
# 6   Homme  21 - 25   5   3   5   5   1   4   3   3   5    3    3
# 7   Femme  18 - 20   4   3   1   2   3   3   3   3   3    3    4
# 8   Homme  26 - 30   4   5   2   5   3   4   2   4   3    3    5
# 9   Homme  21 - 25   4   4   1   3   3   3   4   4   4    4    2
# 10  Homme  26 - 30   4   4   1   5   4   4   3   3   4    4    2
# 11  Homme  18 - 20   4   4   2   5   3   4   3   4   3    4    4
# 12  Femme  18 - 20   5   5   4   4   5   5   2   4   3    3    4
# 13  Homme  21 - 25   4   4   1   4   2   4   2   4   4    4    2
# 14  Homme  21 - 25   4   4   4   4   3   3   3   4   3    3    3
# 15  Homme  21 - 25   5   5   3   5   3   4   4   4   5    3    3
# 16  Homme  21 - 25   5   4   4   4   3   3   4   4   3    3    4
# 17  Femme  21 - 25   5   3   2   4   4   4   3   4   3    4    2
# 18  Homme  21 - 25   5   4   1   5   5   4   4   3   3    2    4
# 19  Femme  18 - 20   5   5   2   4   3   4   3   3   4    3    3
# 20  Homme  21 - 25   2   5   2   5   4   4   3   4   4    4    3
# 21  Homme  18 - 20   4   4   3   5   3   4   4   3   5    4    1
# 22  Femme  18 - 20   5   4   3   4   3   4   2   4   3    4    4
# 23  Homme  21 - 25   4   4   2   4   3   4   2   3   5    2    3
# 24  Homme  26 - 30   4   4   2   5   3   4   3   3   3    3    4
# 25  Homme  21 - 25   5   4   2   4   4   4   2   4   3    3    4
# 26  Femme  21 - 25   4   4   3   4   2   4   3   3   4    4    3
# 27  Homme  31 - 35   4   4   3   4   3   4   4   4   4    4    2

# %%
likert["T1"].mean()
# Out:
# 4.428571428571429

# %%
# ON DEFINI UN GROUPE D'AGE DE LA SAE
age18_20 = likert.loc[likert["Age"] == "18 - 20"]
age21_25 = likert.loc[likert["Age"] == "21 - 25"]
age26_30 = likert.loc[likert["Age"] == "26 - 30"]
age31_35 = likert.loc[likert["Age"] == "31 - 35"]

# %%
age18_20.std().plot(color='pink', label='18 - 20')
age21_25.std().plot(color='green', label='21 - 25')
age26_30.std().plot(color='red', label='26 - 30')
age31_35.std().plot(color='blue', label='31 - 35' )
plt.legend()
plt.title("Déviation standard des âge différents")
plt.xlabel("Questions")
plt.ylabel("Déviation Standard")
# Out:
# C:\Users\Florian\AppData\Local\Temp\ipykernel_1156\2894615935.py:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   age18_20.std().plot(color='pink', label='18 - 20')
# C:\Users\Florian\AppData\Local\Temp\ipykernel_1156\2894615935.py:2: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   age21_25.std().plot(color='green', label='21 - 25')
# C:\Users\Florian\AppData\Local\Temp\ipykernel_1156\2894615935.py:3: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   age26_30.std().plot(color='red', label='26 - 30')
# C:\Users\Florian\AppData\Local\Temp\ipykernel_1156\2894615935.py:4: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   age31_35.std().plot(color='blue', label='31 - 35' )
# Text(0, 0.5, 'Déviation Standard')

# %%
categorie_homme = likert.loc[likert["Sexe"] == "Homme"]
categorie_femme = likert.loc[likert["Sexe"] == "Femme"]


categorie_homme.std().plot(color='blue', label='Homme')
categorie_femme.std().plot(color='pink', label='Femme')

plt.legend()
plt.title("Déviation standard des sexe différents")
plt.xlabel("Questions")
plt.ylabel("Déviation Standard")
# Out:
# C:\Users\Florian\AppData\Local\Temp\ipykernel_1156\852997438.py:5: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   categorie_homme.std().plot(color='blue', label='Homme')
# C:\Users\Florian\AppData\Local\Temp\ipykernel_1156\852997438.py:6: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   categorie_femme.std().plot(color='pink', label='Femme')
# Text(0, 0.5, 'Déviation Standard')

# %%
likert.std()
# Out:
# C:\Users\Florian\AppData\Local\Temp\ipykernel_1156\3790124687.py:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   likert.std()
# T1     0.690066
# T2     0.611832
# T3     1.104943
# T4     0.722832
# T5     0.944911
# T6     0.566947
# T7     0.813250
# T8     0.547964
# T9     0.835711
# T10    0.741798
# T11    0.970463
# dtype: float64

# %%
stats.f_oneway(age18_20["T1"],likert["T2"],likert["T3"],likert["T4"],likert["T5"],likert["T6"],likert["T7"],likert["T8"],likert["T9"],likert["T10"],likert["T11"])

def useANOVA(df):
    result = stats.f_oneway(df["T1"],df["T2"],df["T3"],df["T4"],df["T5"],df["T6"],df["T7"],df["T8"],df["T9"],df["T10"],df["T11"])
    print(result)
    return result
useANOVA(age18_20)
useANOVA(age21_25).pvalue
#x = les sections
#y = pvalue
#Je veux utiliser ANOVA sur que les game prog
x = ["18-20", "21-25", "26-30", "31-35"]
y = [useANOVA(age18_20).pvalue, useANOVA(age21_25).pvalue, useANOVA(age26_30).pvalue, useANOVA(age31_35).pvalue]
plt.xlabel('age')
plt.ylabel("pvalue")
plt.plot(x,y)
plt.show()
# Out:
# F_onewayResult(statistic=5.667341772151901, pvalue=2.620385011574722e-06)
# F_onewayResult(statistic=6.015126050420168, pvalue=1.115722528937641e-07)
# F_onewayResult(statistic=5.667341772151901, pvalue=2.620385011574722e-06)
# F_onewayResult(statistic=6.015126050420168, pvalue=1.115722528937641e-07)
# F_onewayResult(statistic=6.364285714285715, pvalue=2.2855466064019057e-05)
# F_onewayResult(statistic=nan, pvalue=nan)
# C:\Users\Florian\PycharmProjects\norto\venv\lib\site-packages\scipy\stats\_stats_py.py:3869: DegenerateDataWarning: all input arrays have length 1.  f_oneway requires that at least one input has length greater than 1.
#   warnings.warn(stats.DegenerateDataWarning(msg))
